# %% [markdown]
# # Etapa 03 -  toneladas de cimento produzido | Estado de Santa Catarina

# %% [markdown]
# ## Gerar números aleatórios que representem a atividade industrial (ex: toneladas de cimento produzido). Utilize alguma indústria do estado para basear seus códigos

# %%
# De inicio nao sei como resolver está questão, mas pretendo gerar graficos que apresentem a quantidade de cimento produzida no semestre de 2011.

# %%
# os dados foram retirados a partir do link: https://fiesc.com.br/pt-br/node/7680 - Tabela "Produção de cimento por Regioes e estados".import pandas as pd

# Dados de exemplo
dados = {
    'Estado': ['Parana', 'Santa Catarina', 'Rio Grande do Sul'],
    'Janeiro': [447.253, 38.517, 172.330],
    'Fevereiro': [447.250, 37.651, 164.415],
    'Março': [490.749, 36.111, 181.258],
    'Abril': [476.523, 38.840, 181.614],
    'Maio': [491.751, 41.141, 191.398],
    'Junho': [474.696, 75.201, 185.134]
}

# Criando um DataFrame do pandas com os dados
df = pd.DataFrame(dados)

# Exibindo o DataFrame
print(df)
# Out:
#               Estado  Janeiro  Fevereiro    Março    Abril     Maio    Junho
# 0             Parana  447.253    447.250  490.749  476.523  491.751  474.696
# 1     Santa Catarina   38.517     37.651   36.111   38.840   41.141   75.201
# 2  Rio Grande do Sul  172.330    164.415  181.258  181.614  191.398  185.134

# %%
# Criando um DataFrame do pandas com os dados
df = pd.DataFrame(dados)

# Definindo os meses como índice para facilitar a plotagem
df.set_index('Estado', inplace=True)

# Plotando o gráfico
df.T.plot(marker='o', figsize=(10, 6))

# Definindo o título e os rótulos dos eixos
plt.title('Produção de Cimento por Estado (Janeiro a Junho)')
plt.xlabel('Mês')
plt.ylabel('Toneladas')

# Adicionando a legenda
plt.legend(title='Estado')

# Exibindo o gráfico
plt.grid(True)
plt.tight_layout()
plt.show()
